# %% [markdown]
# # APPLICATION 10 - NEURAL STYLE NETWORK

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import models, transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def get_image(path, img_transform, size = (300,300)):
    image = Image.open(path)
    image = image.resize(size, Image.LANCZOS)
    image = img_transform(image).unsqueeze(0)
    return image.to(device)

def get_gram(m):
    _, c, h, w = m.size()
    m = m.view(c, h * w)
    m = torch.mm(m, m.t()) 
    return m

def denormalize_img(inp):
    inp     = inp.numpy().transpose((1, 2, 0))
    mean    = np.array([0.485, 0.456, 0.406])
    std     = np.array([0.229, 0.224, 0.225])
    inp     = std * inp + mean
    inp     = np.clip(inp, 0, 1)
    return inp

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        self.selected_layers = [3, 8, 15, 22]
        self.vgg = models.vgg16(pretrained=True).features
        
    def forward(self, x):
        layer_features = []
        for layer_number, layer in self.vgg._modules.items():
            x = layer(x)
            if int(layer_number) in self.selected_layers:
                layer_features.append(x)
        return layer_features

# %%
img_transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))])

content_img     = get_image('content.jpg', img_transform)
style_img       = get_image('style.jpg', img_transform)
generated_img   = content_img.clone()    # or nn.Parameter(torch.FloatTensor(content_img.size()))
generated_img.requires_grad = True

optimizer = torch.optim.Adam([generated_img], lr=0.003, betas=[0.5, 0.999])
encoder   = FeatureExtractor().to(device)

for p in encoder.parameters():
    p.requires_grad = False

# %%
content_weight = 1
style_weight = 100

for epoch in range(500):
    
    content_features = encoder(content_img)
    style_features = encoder(style_img)
    generated_features = encoder(generated_img)
    
    content_loss = torch.mean((content_features[-1] - generated_features[-1])**2)  

    style_loss = 0
    for gf, sf in zip(generated_features, style_features):
        _, c, h, w = gf.size()
        gram_gf = get_gram(gf)
        gram_sf = get_gram(sf)
        style_loss += torch.mean((gram_gf - gram_sf)**2)  / (c * h * w) 

    loss = content_weight * content_loss + style_weight * style_loss 
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print ('Epoch [{}]\tContent Loss: {:.4f}\tStyle Loss: {:.4f}'.format(epoch, content_loss.item(), style_loss.item()))
# Out:
# Epoch [0]	Content Loss: 0.0000	Style Loss: 1876.1628
# Epoch [10]	Content Loss: 0.4513	Style Loss: 1495.8291
# Epoch [20]	Content Loss: 0.9162	Style Loss: 1283.4924
# Epoch [30]	Content Loss: 1.2886	Style Loss: 1132.3129
# Epoch [40]	Content Loss: 1.5866	Style Loss: 1015.4857
# Epoch [50]	Content Loss: 1.8256	Style Loss: 921.3336
# Epoch [60]	Content Loss: 2.0262	Style Loss: 842.8416
# Epoch [70]	Content Loss: 2.1962	Style Loss: 775.8549
# Epoch [80]	Content Loss: 2.3484	Style Loss: 717.6972
# Epoch [90]	Content Loss: 2.4827	Style Loss: 666.8154
# Epoch [100]	Content Loss: 2.6012	Style Loss: 621.7711
# Epoch [110]	Content Loss: 2.7060	Style Loss: 581.5225
# Epoch [120]	Content Loss: 2.8003	Style Loss: 545.2792
# Epoch [130]	Content Loss: 2.8837	Style Loss: 512.3268
# Epoch [140]	Content Loss: 2.9599	Style Loss: 482.1216
# Epoch [150]	Content Loss: 3.0294	Style Loss: 454.2315
# Epoch [160]	Content Loss: 3.0913	Style Loss: 428.3515
# Epoch [170]	Content Loss: 3.1494	Style Loss: 404.2357
# Epoch [180]	Content Loss: 3.2024	Style Loss: 381.6892
# Epoch [190]	Content Loss: 3.2525	Style Loss: 360.5314
# Epoch [200]	Content Loss: 3.2987	Style Loss: 340.6287
# Epoch [210]	Content Loss: 3.3406	Style Loss: 321.8749
# Epoch [220]	Content Loss: 3.3819	Style Loss: 304.1913
# Epoch [230]	Content Loss: 3.4205	Style Loss: 287.5086
# Epoch [240]	Content Loss: 3.4557	Style Loss: 271.7818
# Epoch [250]	Content Loss: 3.4878	Style Loss: 256.9610
# Epoch [260]	Content Loss: 3.5181	Style Loss: 242.9556
# Epoch [270]	Content Loss: 3.5459	Style Loss: 229.7294
# Epoch [280]	Content Loss: 3.5743	Style Loss: 217.2375
# Epoch [290]	Content Loss: 3.6009	Style Loss: 205.4484
# Epoch [300]	Content Loss: 3.6267	Style Loss: 194.3280
# Epoch [310]	Content Loss: 3.6509	Style Loss: 183.8466
# Epoch [320]	Content Loss: 3.6740	Style Loss: 173.9726
# Epoch [330]	Content Loss: 3.6962	Style Loss: 164.6786
# Epoch [340]	Content Loss: 3.7180	Style Loss: 155.9523
# Epoch [350]	Content Loss: 3.7383	Style Loss: 147.7765
# Epoch [360]	Content Loss: 3.7580	Style Loss: 140.1264
# Epoch [370]	Content Loss: 3.7763	Style Loss: 132.9785
# Epoch [380]	Content Loss: 3.7930	Style Loss: 126.3101
# Epoch [390]	Content Loss: 3.8084	Style Loss: 120.0980
# Epoch [400]	Content Loss: 3.8234	Style Loss: 114.3151
# Epoch [410]	Content Loss: 3.8387	Style Loss: 108.9340
# Epoch [420]	Content Loss: 3.8530	Style Loss: 103.9305
# Epoch [430]	Content Loss: 3.8663	Style Loss: 99.2773
# Epoch [440]	Content Loss: 3.8789	Style Loss: 94.9518
# Epoch [450]	Content Loss: 3.8910	Style Loss: 90.9290
# Epoch [460]	Content Loss: 3.9031	Style Loss: 87.1885
# Epoch [470]	Content Loss: 3.9150	Style Loss: 83.7072
# Epoch [480]	Content Loss: 3.9264	Style Loss: 80.4684
# Epoch [490]	Content Loss: 3.9370	Style Loss: 77.4553

# %%
inp = generated_img.detach().cpu().squeeze()
inp = denormalize_img(inp)
plt.imshow(inp)
